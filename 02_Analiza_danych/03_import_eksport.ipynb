# %% [markdown]
# <a href="https://colab.research.google.com/github/DGluszyk/data-science-bootcamp/blob/main/02_Analiza_danych/03_import_eksport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
def fetch_financial_data(company='AMZN'):
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')
df = fetch_financial_data('META')
# Out:
# <bound method NDFrame.head of                Open      High      Low   Close    Volume
# Date
# 2026-03-13  623.890  629.1699  609.550  613.71  18957637
# 2026-03-12  648.750  653.5000  636.900  638.18  11617485
# 2026-03-11  654.760  659.1200  648.360  654.86   8977162
# 2026-03-10  653.560  660.3000  649.000  653.91   9859250
# 2026-03-09  634.780  647.7500  626.780  647.34  13489742
# ...             ...       ...      ...     ...       ...
# 2021-03-19  281.220  292.8000  281.195  290.11  38930536
# 2021-03-18  279.870  285.1899  278.280  278.62  18754853
# 2021-03-17  275.705  286.2300  275.410  284.01  21315044
# 2021-03-16  276.085  282.1400  274.800  279.28  22437665
# 2021-03-15  269.080  275.9600  268.500  273.75  16856746
#
# [1256 rows x 5 columns]>

# %%
df.head()
# Out:
#               Open      High     Low   Close    Volume
# Date
# 2026-03-13  623.89  629.1699  609.55  613.71  18957637
# 2026-03-12  648.75  653.5000  636.90  638.18  11617485
# 2026-03-11  654.76  659.1200  648.36  654.86   8977162
# 2026-03-10  653.56  660.3000  649.00  653.91   9859250
# 2026-03-09  634.78  647.7500  626.78  647.34  13489742

# %%
df.to_csv('meta.csv')

# %%
df_nov = df[(df.index.month == 11) & (df.index.year == 2025)]
df_nov
# Out:
#                Open      High       Low   Close    Volume
# Date
# 2025-11-28  636.075  648.0500  635.5000  647.95  11033198
# 2025-11-26  637.690  638.3600  631.6300  633.61  15209481
# 2025-11-25  624.000  637.0450  618.3000  636.22  25212978
# 2025-11-24  598.720  616.7000  597.6301  613.05  23554932
# 2025-11-21  588.500  598.1200  581.8600  594.25  21052624
# 2025-11-20  603.500  606.7200  583.3500  589.15  20603024
# 2025-11-19  593.715  595.3300  581.2500  590.32  24744703
# 2025-11-18  591.600  603.6600  583.7800  597.69  25500647
# 2025-11-17  609.035  611.6900  595.4000  602.01  16501331
# 2025-11-14  601.790  613.6800  595.2000  609.46  20724146
# 2025-11-13  613.070  617.6500  603.0000  609.89  20973845
# 2025-11-12  628.130  628.9900  607.7700  609.01  24493272
# 2025-11-11  628.000  629.5600  619.3900  627.08  13302187
# 2025-11-10  631.090  635.0000  618.1050  631.76  19245000
# 2025-11-07  616.485  622.1348  601.2000  621.71  29946826
# ...

# %%
df_nov.to_csv('meta_nov.csv')

# %%
new_df = pd.read_csv('meta_nov.csv')
new_df
# Out:
#           Date     Open      High       Low   Close    Volume
# 0   2025-11-28  636.075  648.0500  635.5000  647.95  11033198
# 1   2025-11-26  637.690  638.3600  631.6300  633.61  15209481
# 2   2025-11-25  624.000  637.0450  618.3000  636.22  25212978
# 3   2025-11-24  598.720  616.7000  597.6301  613.05  23554932
# 4   2025-11-21  588.500  598.1200  581.8600  594.25  21052624
# 5   2025-11-20  603.500  606.7200  583.3500  589.15  20603024
# 6   2025-11-19  593.715  595.3300  581.2500  590.32  24744703
# 7   2025-11-18  591.600  603.6600  583.7800  597.69  25500647
# 8   2025-11-17  609.035  611.6900  595.4000  602.01  16501331
# 9   2025-11-14  601.790  613.6800  595.2000  609.46  20724146
# 10  2025-11-13  613.070  617.6500  603.0000  609.89  20973845
# 11  2025-11-12  628.130  628.9900  607.7700  609.01  24493272
# 12  2025-11-11  628.000  629.5600  619.3900  627.08  13302187
# 13  2025-11-10  631.090  635.0000  618.1050  631.76  19245000
# ...

# %%
df_nov.to_excel('meta_nov.xlsx')

# %%
new_df = pd.read_excel('meta_nov.xlsx', index_col=0)
new_df
# Out:
#                Open      High       Low   Close    Volume
# Date
# 2025-11-28  636.075  648.0500  635.5000  647.95  11033198
# 2025-11-26  637.690  638.3600  631.6300  633.61  15209481
# 2025-11-25  624.000  637.0450  618.3000  636.22  25212978
# 2025-11-24  598.720  616.7000  597.6301  613.05  23554932
# 2025-11-21  588.500  598.1200  581.8600  594.25  21052624
# 2025-11-20  603.500  606.7200  583.3500  589.15  20603024
# 2025-11-19  593.715  595.3300  581.2500  590.32  24744703
# 2025-11-18  591.600  603.6600  583.7800  597.69  25500647
# 2025-11-17  609.035  611.6900  595.4000  602.01  16501331
# 2025-11-14  601.790  613.6800  595.2000  609.46  20724146
# 2025-11-13  613.070  617.6500  603.0000  609.89  20973845
# 2025-11-12  628.130  628.9900  607.7700  609.01  24493272
# 2025-11-11  628.000  629.5600  619.3900  627.08  13302187
# 2025-11-10  631.090  635.0000  618.1050  631.76  19245000
# 2025-11-07  616.485  622.1348  601.2000  621.71  29946826
# ...

# %%
df = pd.read_csv('london_bike.csv')

# %%
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# ...

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df = df.set_index('timestamp')

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# ...

# %%
def fetch_financial_data(company='AMZN'):
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')
apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1255 entries, 2026-03-13 to 2021-03-16
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1255 non-null   float64
#  1   High    1255 non-null   float64
#  2   Low     1255 non-null   float64
#  3   Close   1255 non-null   float64
#  4   Volume  1255 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.8 KB

# %%
apple.head()
# Out:
#                Open    High       Low   Close    Volume
# Date
# 2026-03-13  255.480  256.33  249.5200  250.12  36929988
# 2026-03-12  258.660  258.95  254.1800  255.76  40794020
# 2026-03-11  261.090  262.13  259.5500  260.81  26218927
# 2026-03-10  257.645  262.48  256.9500  260.72  30590765
# 2026-03-09  255.690  261.15  253.6805  259.89  38218533

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns]

# %%
apple
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2026-03-13     255.480     256.330   249.5200      250.120      36929988
# 2026-03-12     258.660     258.950   254.1800      255.760      40794020
# 2026-03-11     261.090     262.130   259.5500      260.810      26218927
# 2026-03-10     257.645     262.480   256.9500      260.720      30590765
# 2026-03-09     255.690     261.150   253.6805      259.890      38218533
# ...                ...         ...        ...          ...           ...
# 2021-03-22     117.316     120.764   117.2490      120.292     114792778
# 2021-03-19     116.904     118.377   116.6790      116.983     190325355
# 2021-03-18     119.793     120.087   117.3060      117.504     124596247
# 2021-03-17     120.931     122.709   119.2700      121.629     114813654
# 2021-03-16     122.552     124.025   121.5790      122.425     118193771
#
# [1255 rows x 5 columns]

# %%
df = pd.concat(objs=[apple, amazon, google, uber], axis=1)

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')
df.describe().T
# Out:
#                 count        mean         std         min         25%  \
# apple_open    1255.00      184.67       41.73      116.55      148.71
# apple_high    1255.00      186.67       42.02      117.39      151.17
# apple_low     1255.00      182.86       41.39      115.88      147.22
# apple_close   1255.00      184.85       41.71      116.90      149.03
# apple_volume  1255.00 68322900.21 29242208.41 17910574.00 47550856.50
# amazon_open   1255.00      165.91       42.12       82.80      132.06
# amazon_high   1255.00      167.87       42.28       83.48      133.63
# amazon_low    1255.00      163.81       41.82       81.43      130.46
# amazon_close  1255.00      165.89       42.06       81.82      132.03
# amazon_volume 1255.00 56758879.04 27049901.54 11420543.00 39509209.00
# google_open   1255.00      154.69       55.66       85.09      118.36
# google_high   1255.00      156.49       56.30       86.21      119.74
# ...

# %%
df.corr()
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.47
# apple_high           1.00        1.00       1.00         1.00         -0.46
# apple_low            1.00        1.00       1.00         1.00         -0.48
# apple_close          1.00        1.00       1.00         1.00         -0.47
# apple_volume        -0.47       -0.46      -0.48        -0.47          1.00
# amazon_open          0.76        0.76       0.76         0.76         -0.29
# amazon_high          0.76        0.76       0.76         0.76         -0.28
# amazon_low           0.76        0.76       0.76         0.76         -0.30
# amazon_close         0.76        0.76       0.76         0.76         -0.29
# amazon_volume       -0.40       -0.39      -0.41        -0.40          0.57
# google_open          0.87        0.87       0.87         0.87         -0.35
# ...

# %%
df.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'uber_open', 'uber_high', 'uber_low',
#        'uber_close', 'uber_volume'],
#       dtype='object')

# %%
closes = [col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0.76          0.87        0.78
# amazon_close         0.76          1.00          0.81        0.87
# google_close         0.87          0.81          1.00        0.74
# uber_close           0.78          0.87          0.74        1.00

# %%
closes = [col for col in df.columns if col.endswith('close') or col.endswith('volume')]
closes
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %%
uber.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2026-03-13      73.30      74.87     72.69       73.33     16400650
# 2026-03-12      74.87      75.85     72.59       72.97     17082705
# 2026-03-11      74.54      75.60     73.55       74.97     21010783
# 2026-03-10      73.99      74.12     72.18       72.36     17581464
# 2026-03-09      74.17      74.54     71.94       73.84     21208861

# %%
uber_6 = uber[uber.index.month == 6]
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-06-30      91.69      93.39     91.52       93.30     16155270
# 2025-06-27      91.86      92.51     89.97       91.53     24731168
# 2025-06-26      91.30      94.38     90.88       93.12     23657765
# 2025-06-25      91.56      92.89     90.60       90.90     17400840
# 2025-06-24      87.99      92.48     87.91       91.65     38925080
# ...               ...        ...       ...         ...          ...
# 2021-06-07      50.49      51.22     49.75       50.76     16466233
# 2021-06-04      49.56      50.22     49.07       50.18     10409827
# 2021-06-03      50.43      50.50     48.53       48.70     14712859
# 2021-06-02      51.19      51.41     50.55       50.79     13484205
# 2021-06-01      51.62      51.66     49.84       50.98     16583752
#
# [103 rows x 5 columns]

# %%
uber_7 = uber[uber.index.month == 7]
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-07-31      87.53      88.84     86.61       87.75     16922440
# 2025-07-30      87.45      87.81     86.47       87.64     16862770
# 2025-07-29      88.89      89.16     86.36       87.11     24966230
# 2025-07-28      91.33      92.35     90.24       90.60     11606054
# 2025-07-25      90.50      91.38     89.50       91.29     13864112
# ...               ...        ...       ...         ...          ...
# 2021-07-08      47.16      48.21     46.57       47.55     24930159
# 2021-07-07      50.80      51.03     48.54       48.68     24559506
# 2021-07-06      50.60      52.03     50.40       50.80     21357834
# 2021-07-02      50.57      51.83     50.39       51.71     13698243
# 2021-07-01      50.88      51.60     50.02       50.59     17732585
#
# [105 rows x 5 columns]

# %%
uber_67 = pd.concat(objs=[uber_6, uber_7])
uber_67
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-06-30      91.69      93.39     91.52       93.30     16155270
# 2025-06-27      91.86      92.51     89.97       91.53     24731168
# 2025-06-26      91.30      94.38     90.88       93.12     23657765
# 2025-06-25      91.56      92.89     90.60       90.90     17400840
# 2025-06-24      87.99      92.48     87.91       91.65     38925080
# ...               ...        ...       ...         ...          ...
# 2021-07-08      47.16      48.21     46.57       47.55     24930159
# 2021-07-07      50.80      51.03     48.54       48.68     24559506
# 2021-07-06      50.60      52.03     50.40       50.80     21357834
# 2021-07-02      50.57      51.83     50.39       51.71     13698243
# 2021-07-01      50.88      51.60     50.02       50.59     17732585
#
# [208 rows x 5 columns]

# %% [markdown]
# ### Google App Store Data case

# %%
import pandas as pd

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/appstore_games.csv'
df_raw = pd.read_csv(url)
df_raw.head()
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# ...

# %%
df_raw.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   URL                           17007 non-null  object
#  1   ID                            17007 non-null  int64
#  2   Name                          17007 non-null  object
#  3   Subtitle                      5261 non-null   object
#  4   Icon URL                      17007 non-null  object
#  5   Average User Rating           7561 non-null   float64
#  6   User Rating Count             7561 non-null   float64
#  7   Price                         16983 non-null  float64
#  8   In-app Purchases              7683 non-null   object
#  9   Description                   17007 non-null  object
#  10  Developer                     17007 non-null  object
#  11  Age Rating                    17007 non-null  object
# ...

# %%
df = df.drop(columns=['URL', 'Icon URL', 'Subtitle', 'Description', 'In-app Purchases'])
df.head()
# Out:
#           ID           Name  Average User Rating  User Rating Count  Price  \
# 0  284921427         Sudoku                  4.0             3553.0   2.99
# 1  284926400        Reversi                  3.5              284.0   1.99
# 2  284946595        Morocco                  3.0             8376.0   0.00
# 3  285755462  Sudoku (Free)                  3.5           190394.0   0.00
# 4  285831220   Senet Deluxe                  3.5               28.0   2.99
#
#                   Developer Age Rating  \
# 0  Mighty Mighty Good Games         4+
# 1          Kiss The Machine         4+
# 2               Bayou Games         4+
# 3  Mighty Mighty Good Games         4+
# 4           RoGame Software         4+
#
#                                            Languages        Size  \
# 0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 1                                                 EN  12328960.0
# 2                                                 EN    674816.0
# ...

# %%
df = df.set_index('ID')
df.head()
# Out:
#                     Name  Average User Rating  User Rating Count  Price  \
# ID
# 284921427         Sudoku                  4.0             3553.0   2.99
# 284926400        Reversi                  3.5              284.0   1.99
# 284946595        Morocco                  3.0             8376.0   0.00
# 285755462  Sudoku (Free)                  3.5           190394.0   0.00
# 285831220   Senet Deluxe                  3.5               28.0   2.99
#
#                           Developer Age Rating  \
# ID
# 284921427  Mighty Mighty Good Games         4+
# 284926400          Kiss The Machine         4+
# 284946595               Bayou Games         4+
# 285755462  Mighty Mighty Good Games         4+
# 285831220           RoGame Software         4+
#
#                                                    Languages        Size  \
# ID
# 284921427  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 284926400                                                 EN  12328960.0
# ...

# %%
df.describe()
# Out:
#        Average User Rating  User Rating Count         Price          Size
# count          7561.000000       7.561000e+03  16983.000000  1.700600e+04
# mean              4.060905       3.306531e+03      0.813419  1.157064e+08
# std               0.751428       4.232256e+04      7.835732  2.036477e+08
# min               1.000000       5.000000e+00      0.000000  5.132800e+04
# 25%               3.500000       1.200000e+01      0.000000  2.295014e+07
# 50%               4.500000       4.600000e+01      0.000000  5.676895e+07
# 75%               4.500000       3.090000e+02      0.000000  1.330271e+08
# max               5.000000       3.032734e+06    179.990000  4.005591e+09

# %%
df.describe().T
# Out:
#                        count          mean           std      min         25%  \
# Average User Rating   7561.0  4.060905e+00  7.514275e-01      1.0         3.5
# User Rating Count     7561.0  3.306531e+03  4.232256e+04      5.0        12.0
# Price                16983.0  8.134187e-01  7.835732e+00      0.0         0.0
# Size                 17006.0  1.157064e+08  2.036477e+08  51328.0  22950144.0
#
#                             50%          75%           max
# Average User Rating         4.5          4.5  5.000000e+00
# User Rating Count          46.0        309.0  3.032734e+06
# Price                       0.0          0.0  1.799900e+02
# Size                 56768954.0  133027072.0  4.005591e+09

# %%
df.describe(include=['object']).T
# Out:
#                               count unique  \
# Name                          17007  16847
# Developer                     17007   8693
# Age Rating                    17007      4
# Languages                     16947    990
# Primary Genre                 17007     21
# Genres                        17007   1004
# Original Release Date         17007   3084
# Current Version Release Date  17007   2512
#
#                                                                      top  \
# Name                                          10-in-1 Board Games BA.net
# Developer                     Tapps Tecnologia da Informa\xe7\xe3o Ltda.
# Age Rating                                                            4+
# Languages                                                             EN
# Primary Genre                                                      Games
# Genres                                           Games, Strategy, Puzzle
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Average User Rating', 'User Rating Count', 'Price',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df.columns = [col.lower().replace(' ', '_') for col in df.columns]
df.head()
# Out:
#                     name  average_user_rating  user_rating_count  price  \
# ID
# 284921427         Sudoku                  4.0             3553.0   2.99
# 284926400        Reversi                  3.5              284.0   1.99
# 284946595        Morocco                  3.0             8376.0   0.00
# 285755462  Sudoku (Free)                  3.5           190394.0   0.00
# 285831220   Senet Deluxe                  3.5               28.0   2.99
#
#                           developer age_rating  \
# ID
# 284921427  Mighty Mighty Good Games         4+
# 284926400          Kiss The Machine         4+
# 284946595               Bayou Games         4+
# 285755462  Mighty Mighty Good Games         4+
# 285831220           RoGame Software         4+
#
#                                                    languages        size  \
# ID
# 284921427  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 284926400                                                 EN  12328960.0
# ...

# %%
df.average_user_rating
# Out:
# ID
# 284921427     4.0
# 284926400     3.5
# 284946595     3.0
# 285755462     3.5
# 285831220     3.5
#              ...
# 1474626442    NaN
# 1474919257    NaN
# 1474962324    NaN
# 1474963671    NaN
# 1475076711    NaN
# Name: average_user_rating, Length: 17007, dtype: float64

# %%
df.head(2)
# Out:
#               name  average_user_rating  user_rating_count  price  \
# ID
# 284921427   Sudoku                  4.0             3553.0   2.99
# 284926400  Reversi                  3.5              284.0   1.99
#
#                           developer age_rating  \
# ID
# 284921427  Mighty Mighty Good Games         4+
# 284926400          Kiss The Machine         4+
#
#                                                    languages        size  \
# ID
# 284921427  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 284926400                                                 EN  12328960.0
#
#           primary_genre                   genres original_release_date  \
# ID
# 284921427         Games  Games, Strategy, Puzzle            11/07/2008
# 284926400         Games   Games, Strategy, Board            11/07/2008
#
#           current_version_release_date
# ID
# 284921427                   30/05/2017
# 284926400                   17/05/2018

# %%
df.primary_genre.value_counts()
# Out:
# primary_genre
# Games                16286
# Education              222
# Entertainment          198
# Utilities               77
# Sports                  60
# Reference               32
# Stickers                29
# Finance                 18
# Business                16
# Productivity            15
# Lifestyle               10
# Social Networking        9
# Book                     9
# News                     7
# Health & Fitness         5
# Food & Drink             4
# Music                    3
# Navigation               3
# Medical                  2
# Travel                   1
# Shopping                 1
# Name: count, dtype: int64

# %%
df.primary_genre.value_counts().nlargest(5)
# Out:
# primary_genre
# Games            16286
# Education          222
# Entertainment      198
# Utilities           77
# Sports              60
# Name: count, dtype: int64

# %%
df.primary_genre.value_counts().nlargest(5).index
# Out:
# Index(['Games', 'Education', 'Entertainment', 'Utilities', 'Sports'], dtype='object', name='primary_genre')

# %%
list[df.primary_genre.value_counts().nlargest(5).index]
# Out:
# list[Index(['Games', 'Education', 'Entertainment', 'Utilities', 'Sports'], dtype='object', name='primary_genre')]

# %%
df.age_rating.value_counts()
# Out:
# age_rating
# 4+     11806
# 9+      2481
# 12+     2055
# 17+      665
# Name: count, dtype: int64

# %%
type(df.age_rating.value_counts())
# Out:
# pandas.core.series.Series

# %%
df.age_rating.value_counts().plot()
# Out:
# <Axes: xlabel='age_rating'>

# %%
import seaborn as sns
sns.set()
df.age_rating.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.price.value_counts()
# Out:
# price
# 0.00      14212
# 0.99       1078
# 1.99        515
# 2.99        471
# 4.99        237
# 3.99        163
# 9.99         88
# 11.99        59
# 5.99         42
# 6.99         32
# 179.99       30
# 7.99         17
# 8.99         13
# 19.99         9
# 14.99         4
# 12.99         3
# 16.99         2
# 29.99         2
# 99.99         1
# 139.99        1
# 37.99         1
# 36.99         1
# 18.99         1
# 59.99         1
# Name: count, dtype: int64

# %%
df.average_user_rating.value_counts()
# Out:
# average_user_rating
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: count, dtype: int64

# %%
df.languages.value_counts()
# Out:
# languages
# EN                                                                                    12467
# EN, ZH                                                                                  354
# CS, NL, EN, FR, DE, IT, JA, KO, PL, PT, RU, ZH, ES, SV, ZH, TR                          277
# EN, ZH, ZH                                                                              248
# EN, DE                                                                                  147
#                                                                                       ...
# EN, MS, ZH                                                                                1
# ZH, EN, FR, DE, KO, RU, ES                                                                1
# EN, FR, DE, ID, JA, KO, RU, ZH, ES, ZH, VI                                                1
# AR, DA, NL, EN, FI, FR, DE, ID, IT, JA, KO, NO, PL, PT, RU, ZH, ES, SV, TH, ZH, TR        1
# ...

# %%
df.languages.str.split(', ')
# Out:
# ID
# 284921427     [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 284926400                                                  [EN]
# 284946595                                                  [EN]
# 285755462     [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 285831220     [DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, R...
#                                     ...
# 1474626442                                                 [EN]
# 1474919257                                                 [EN]
# 1474962324                                                 [EN]
# 1474963671                                                 [EN]
# 1475076711                                             [EN, ZH]
# Name: languages, Length: 17007, dtype: object

# %%
df.languages.str.split(', ').str.len()
# Out:
# ID
# 284921427     17.0
# 284926400      1.0
# 284946595      1.0
# 285755462     17.0
# 285831220     15.0
#               ...
# 1474626442     1.0
# 1474919257     1.0
# 1474962324     1.0
# 1474963671     1.0
# 1475076711     2.0
# Name: languages, Length: 17007, dtype: float64

# %%
df['num_lan'] = df.languages.str.split(', ').str.len()
df
# Out:
#                                  name  average_user_rating  user_rating_count  \
# ID
# 284921427                      Sudoku                  4.0             3553.0
# 284926400                     Reversi                  3.5              284.0
# 284946595                     Morocco                  3.0             8376.0
# 285755462               Sudoku (Free)                  3.5           190394.0
# 285831220                Senet Deluxe                  3.5               28.0
# ...                               ...                  ...                ...
# 1474626442  Stack Puzzle : Rise Tower                  NaN                NaN
# 1474919257                  EachOther                  NaN                NaN
# 1474962324         Rabbit Vs Tortoise                  NaN                NaN
# 1474963671                     FaTaLL                  NaN                NaN
# 1475076711   The Three Kingdoms :Bomb                  NaN                NaN
#
# ...

# %%
df.num_lan.value_counts().nlargest(10)
# Out:
# num_lan
# 1.0     12566
# 2.0      1102
# 3.0       495
# 16.0      316
# 4.0       261
# 5.0       247
# 6.0       220
# 25.0      171
# 9.0       154
# 11.0      147
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17007 entries, 284921427 to 1475076711
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          17007 non-null  object
#  1   average_user_rating           7561 non-null   float64
#  2   user_rating_count             7561 non-null   float64
#  3   price                         16983 non-null  float64
#  4   developer                     17007 non-null  object
#  5   age_rating                    17007 non-null  object
#  6   languages                     16947 non-null  object
#  7   size                          17006 non-null  float64
#  8   primary_genre                 17007 non-null  object
#  9   genres                        17007 non-null  object
#  10  original_release_date         17007 non-null  object
#  11  current_version_release_date  17007 non-null  object
# ...

# %%
df.average_user_rating.value_counts()
# Out:
# average_user_rating
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: count, dtype: int64

# %%
df.average_user_rating.value_counts(dropna=False)
# Out:
# average_user_rating
# NaN    9446
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#              name  average_user_rating  user_rating_count  price  developer  \
# ID
# 284921427   False                False              False  False      False
# 284926400   False                False              False  False      False
# 284946595   False                False              False  False      False
# 285755462   False                False              False  False      False
# 285831220   False                False              False  False      False
# ...           ...                  ...                ...    ...        ...
# 1474626442  False                 True               True  False      False
# 1474919257  False                 True               True  False      False
# 1474962324  False                 True               True  False      False
# 1474963671  False                 True               True  False      False
# 1475076711  False                 True               True  False      False
#
# ...

# %%
df.isnull().sum()
# Out:
# name                               0
# average_user_rating             9446
# user_rating_count               9446
# price                             24
# developer                          0
# age_rating                         0
# languages                         60
# size                               1
# primary_genre                      0
# genres                             0
# original_release_date              0
# current_version_release_date       0
# num_lan                           60
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# name                            0
# average_user_rating             0
# user_rating_count               0
# price                           0
# developer                       0
# age_rating                      0
# languages                       0
# size                            0
# primary_genre                   0
# genres                          0
# original_release_date           0
# current_version_release_date    0
# num_lan                         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7537 entries, 284921427 to 1474461379
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          7537 non-null   object
#  1   average_user_rating           7537 non-null   float64
#  2   user_rating_count             7537 non-null   float64
#  3   price                         7537 non-null   float64
#  4   developer                     7537 non-null   object
#  5   age_rating                    7537 non-null   object
#  6   languages                     7537 non-null   object
#  7   size                          7537 non-null   float64
#  8   primary_genre                 7537 non-null   object
#  9   genres                        7537 non-null   object
#  10  original_release_date         7537 non-null   object
#  11  current_version_release_date  7537 non-null   object
# ...
